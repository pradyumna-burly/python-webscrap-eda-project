# %% [markdown]
# # Importing Required Libraries

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # Starting with Web Scraping

# %%
# First we'll write logic to scrape contents of one page, then we'll iterate through mutiple pages using looping

# %%
URL = 'https://www.scrapethissite.com/pages/forms/?page_num=1'
headers = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36','Accept-Language':'en-US,en;q=0.5'})

# %%
webpage = requests.get(URL,headers=headers)

# %%
webpage
# Out:
# <Response [200]>

# %%
# Response 200 means good to go
# Response 403/503 are bad requests - Try again after sometime

# %%
#webpage.text

# %%
soup = BeautifulSoup(webpage.content,'html.parser')

# %%
#print(soup.prettify())

# %%
allteams = soup.find_all('tr',class_='team')
#allteams

# %%
team_name = []
year = []
wins = []
losses = []
ot_losses = []
win_percentage = []
goals_for = []
goals_against = []
diff = []
for i in allteams:
    team_name.append(i.find('td',class_='name').text.strip())
    year.append(i.find('td',class_='year').text.strip())
    wins.append(i.find('td',class_='wins').text.strip())
    losses.append(i.find('td',class_='losses').text.strip())
    ot_losses.append(i.find('td',class_='ot-losses').text.strip())
    win_percentage_temp = i.find('td',class_='pct text-success')
    if win_percentage_temp is None:
        win_percentage_temp = i.find('td',class_='pct text-danger')
    if win_percentage_temp:
        win_percentage.append(win_percentage_temp.text.strip())
    goals_for.append(i.find('td',class_='gf').text.strip())
    goals_against.append(i.find('td',class_='ga').text.strip())
    diff_temp = i.find('td',class_='diff text-success')
    if diff_temp is None:
        diff_temp = i.find('td',class_='diff text-danger')
    if diff_temp:
        diff.append(diff_temp.text.strip())

# %%
d = {'Team_Name':team_name,'Year':year,'Wins':wins,'Losses':losses,'ot_losses':ot_losses,'Goals_for':goals_for,'Goals_Against':goals_against,'Difference':diff}

# %%
df=pd.DataFrame(d)

# %%
df
# Out:
#                 Team_Name  Year Wins Losses ot_losses Goals_for Goals_Against  \
# 0           Boston Bruins  1990   44     24                 299           264
# 1          Buffalo Sabres  1990   31     30                 292           278
# 2          Calgary Flames  1990   46     26                 344           263
# 3      Chicago Blackhawks  1990   49     23                 284           211
# 4       Detroit Red Wings  1990   34     38                 273           298
# 5         Edmonton Oilers  1990   37     37                 272           272
# 6        Hartford Whalers  1990   31     38                 238           276
# 7       Los Angeles Kings  1990   46     24                 340           254
# 8   Minnesota North Stars  1990   27     39                 256           266
# 9      Montreal Canadiens  1990   39     30                 273           249
# 10      New Jersey Devils  1990   32     33                 272           264
# 11     New York Islanders  1990   25     45                 223           290
# 12       New York Rangers  1990   36     31                 297           265
# 13    Philadelphia Flyers  1990   33     37                 252           267
# 14    Pittsburgh Penguins  1990   41     33                 342           305
# 15       Quebec Nordiques  1990   16     50                 236           354
# 16        St. Louis Blues  1990   47     22                 310           250
# 17    Toronto Maple Leafs  1990   23     46                 241           318
# 18      Vancouver Canucks  1990   28     43                 243           315
# 19    Washington Capitals  1990   37     36                 258           258
# 20          Winnipeg Jets  1990   26     43                 260           288
# 21          Boston Bruins  1991   36     32                 270           275
# 22         Buffalo Sabres  1991   31     37                 289           299
# 23         Calgary Flames  1991   31     37                 296           305
# 24     Chicago Blackhawks  1991   36     29                 257           236
#
#    Difference
# 0          35
# 1          14
# 2          81
# 3          73
# 4         -25
# 5           0
# 6         -38
# 7          86
# 8         -10
# 9          24
# 10          8
# 11        -67
# 12         32
# 13        -15
# 14         37
# 15       -118
# 16         60
# 17        -77
# 18        -72
# 19          0
# 20        -28
# 21         -5
# 22        -10
# 23         -9
# 24         21

# %%
# Now that we have succesfully able to scrape one pages, we'll apply the logic to fetch records from multiple pages

# %% [markdown]
# # For Scraping data from Multiple Pages

# %%
data_frames = []

for j in range(1,25):

    URL = 'https://www.scrapethissite.com/pages/forms/?page_num={}'.format(j)
    headers = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36','Accept-Language':'en-US,en;q=0.5'})
    webpage = requests.get(URL,headers=headers)
    soup = BeautifulSoup(webpage.content,'html.parser')
    allteams = soup.find_all('tr',class_='team')

    team_name = []
    year = []
    wins = []
    losses = []
    ot_losses = []
    win_percentage = []
    goals_for = []
    goals_against = []
    diff = []
    for i in allteams:
        team_name.append(i.find('td',class_='name').text.strip())
        year.append(i.find('td',class_='year').text.strip())
        wins.append(i.find('td',class_='wins').text.strip())
        losses.append(i.find('td',class_='losses').text.strip())
        ot_losses.append(i.find('td',class_='ot-losses').text.strip())
        win_percentage_temp = i.find('td',class_='pct text-success')
        if win_percentage_temp is None:
            win_percentage_temp = i.find('td',class_='pct text-danger')
        if win_percentage_temp:
            win_percentage.append(win_percentage_temp.text.strip())
        goals_for.append(i.find('td',class_='gf').text.strip())
        goals_against.append(i.find('td',class_='ga').text.strip())
        diff_temp = i.find('td',class_='diff text-success')
        if diff_temp is None:
            diff_temp = i.find('td',class_='diff text-danger')
        if diff_temp:
            diff.append(diff_temp.text.strip())

    d = {'Team_Name':team_name,'Year':year,'Wins':wins,'Losses':losses,'ot_losses':ot_losses,'Goals_for':goals_for,'Goals_Against':goals_against,'Difference':diff}

    df=pd.DataFrame(d)

    data_frames.append(df)

final = pd.concat(data_frames, ignore_index=True)

# %%
final
# Out:
#                Team_Name  Year Wins Losses ot_losses Goals_for Goals_Against  \
# 0          Boston Bruins  1990   44     24                 299           264
# 1         Buffalo Sabres  1990   31     30                 292           278
# 2         Calgary Flames  1990   46     26                 344           263
# 3     Chicago Blackhawks  1990   49     23                 284           211
# 4      Detroit Red Wings  1990   34     38                 273           298
# ..                   ...   ...  ...    ...       ...       ...           ...
# 577  Tampa Bay Lightning  2011   38     36         8       235           281
# 578  Toronto Maple Leafs  2011   35     37        10       231           264
# 579    Vancouver Canucks  2011   51     22         9       249           198
# 580  Washington Capitals  2011   42     32         8       222           230
# 581        Winnipeg Jets  2011   37     35        10       225           246
#
#     Difference
# 0           35
# 1           14
# 2           81
# 3           73
# 4          -25
# ..         ...
# 577        -46
# 578        -33
# 579         51
# 580         -8
# 581        -21
#
# [582 rows x 8 columns]

# %%
# Verification of Obtained data

# %%
print(final.duplicated().sum()) # Prints the number of duplicate rows
# Out:
# 0

# %% [markdown]
# # Extracting the data into excel format

# %%
final.to_excel('scrapeddata.xlsx',index = False)
